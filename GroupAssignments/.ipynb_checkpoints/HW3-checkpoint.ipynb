# %% [markdown]
# Group Assignment #2: Census Data Exploration

# %%
I will be exploring the census data of Los Angles social vulnerbility in this assignment.

# %%
import pandas as pd 
#Use pandas to read csv file

# %%
ni= pd.read_csv('data/National_Risk_Index_Census_Tracts.csv')
#Use pandas to read csv file

# %%
ni.head()
#read the top 5 rows of data
# Out:
#    OBJECTID        NRI_ID    STATE STATEABBRV STATEFIPS   COUNTY COUNTYTYPE  \
# 0         1  T01001020100  Alabama         AL        01  Autauga     County
# 1         2  T01001020200  Alabama         AL        01  Autauga     County
# 2         3  T01001020300  Alabama         AL        01  Autauga     County
# 3         4  T01001020400  Alabama         AL        01  Autauga     County
# 4         5  T01001020501  Alabama         AL        01  Autauga     County
#
#    COUNTYFIPS  STCOFIPS  TRACT  ...     WNTW_ALRP  WNTW_ALRA  WNTW_ALR_NPCTL  \
# 0           1      1001  20100  ...  7.410082e-09   0.000009       32.947366
# 1           1      1001  20200  ...  7.410082e-09   0.000009       33.845738
# 2           1      1001  20300  ...  7.410082e-09   0.000009       33.386570
# 3           1      1001  20400  ...  7.410082e-09   0.000009       32.654955
# 4           1      1001  20501  ...  7.410082e-09   0.000009       32.793527
#
# ...

# %%
ni.shape
# there are 2498 rows and 50 columns in this data
# Out:
# (11040, 470)

# %%
ni.head()
#read the top 5 rows of data
# Out:
#    OBJECTID        NRI_ID    STATE STATEABBRV  STATEFIPS   COUNTY COUNTYTYPE  \
# 0         1  T01001020100  Alabama         AL          1  Autauga     County
# 1         2  T01001020200  Alabama         AL          1  Autauga     County
# 2         3  T01001020300  Alabama         AL          1  Autauga     County
# 3         4  T01001020400  Alabama         AL          1  Autauga     County
# 4         5  T01001020501  Alabama         AL          1  Autauga     County
#
#    COUNTYFIPS  STCOFIPS  TRACT  ...     WNTW_ALRP  WNTW_ALRA  WNTW_ALR_NPCTL  \
# 0           1      1001  20100  ...  7.410082e-09   0.000009       32.947366
# 1           1      1001  20200  ...  7.410082e-09   0.000009       33.845738
# 2           1      1001  20300  ...  7.410082e-09   0.000009       33.386570
# 3           1      1001  20400  ...  7.410082e-09   0.000009       32.654955
# 4           1      1001  20501  ...  7.410082e-09   0.000009       32.793527
#
# ...

# %%
ni.sample
# get some random data in the file
# Out:
# <bound method NDFrame.sample of        OBJECTID        NRI_ID       STATE STATEABBRV  STATEFIPS     COUNTY  \
# 0             1  T01001020100     Alabama         AL          1    Autauga
# 1             2  T01001020200     Alabama         AL          1    Autauga
# 2             3  T01001020300     Alabama         AL          1    Autauga
# 3             4  T01001020400     Alabama         AL          1    Autauga
# 4             5  T01001020501     Alabama         AL          1    Autauga
# ...         ...           ...         ...        ...        ...        ...
# 11035     11036  T06073017305  California         CA          6  San Diego
# 11036     11037  T06073017306  California         CA          6  San Diego
# 11037     11038  T06073017307  California         CA          6  San Diego
# 11038     11039  T06073017308  California         CA          6  San Diego
# 11039     11040  T06073017403  California         CA          6  San Diego
#
# ...

# %% [raw]
# # but I want see the whole columns of the data

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows',None)

# %%
ni.info(verbose=True, show_counts=True)
# get the type of each cloumns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11040 entries, 0 to 11039
# Data columns (total 470 columns):
#  #    Column          Non-Null Count  Dtype
# ---   ------          --------------  -----
#  0    OBJECTID        11040 non-null  int64
#  1    NRI_ID          11040 non-null  object
#  2    STATE           11040 non-null  object
#  3    STATEABBRV      11040 non-null  object
#  4    STATEFIPS       11040 non-null  int64
#  5    COUNTY          11040 non-null  object
#  6    COUNTYTYPE      11040 non-null  object
#  7    COUNTYFIPS      11040 non-null  int64
#  8    STCOFIPS        11040 non-null  int64
#  9    TRACT           11040 non-null  int64
#  10   TRACTFIPS       11040 non-null  int64
#  11   POPULATION      11039 non-null  float64
#  12   BUILDVALUE      11039 non-null  float64
#  13   AGRIVALUE       11039 non-null  float64
#  14   AREA            11039 non-null  float64
#  15   RISK_VALUE      11039 non-null  float64
# ...

# %%
# show top 5 rows of a specific columns
ni.NRI_ID.head()
# Out:
# 0    T01001020100
# 1    T01001020200
# 2    T01001020300
# 3    T01001020400
# 4    T01001020501
# Name: NRI_ID, dtype: object

# %%
#dtype NRI_ID  and statefips ensures that the columns are read in as strings for leading zeros
ni = pd.read_csv(
    'data/National_Risk_Index_Census_Tracts.csv',
    dtype=
    {
        'NRI_ID':str,
        'STATEFIPS': str
    }
)

# %%
# show top 5 rows of a specific columns
ni.STATEFIPS.head()
# Out:
# 0    01
# 1    01
# 2    01
# 3    01
# 4    01
# Name: STATEFIPS, dtype: object

# %%
# I only want the data that was in CA
new = ni[ni['STATEABBRV'] == 'CA']

# %%
new.head(3)
# Out:
#       OBJECTID        NRI_ID       STATE STATEABBRV STATEFIPS   COUNTY  \
# 4200      4201  T06001400100  California         CA        06  Alameda
# 4201      4202  T06001400200  California         CA        06  Alameda
# 4202      4203  T06001400300  California         CA        06  Alameda
#
#      COUNTYTYPE  COUNTYFIPS  STCOFIPS   TRACT  ...  WNTW_ALRP  WNTW_ALRA  \
# 4200     County           1      6001  400100  ...        0.0        0.0
# 4201     County           1      6001  400200  ...        0.0        0.0
# 4202     County           1      6001  400300  ...        0.0        0.0
#
#       WNTW_ALR_NPCTL  WNTW_RISKV  WNTW_RISKS  WNTW_RISKR     NRI_VER  \
# 4200             0.0         0.0         0.0   No Rating  March 2023
# 4201             0.0         0.0         0.0   No Rating  March 2023
# 4202             0.0         0.0         0.0   No Rating  March 2023
#
#                                     GlobalID  SHAPE_Length  SHAPE_Area
# ...

# %% [markdown]
# I want Geo_FIps so I want to delete T0 in NRI_ID

# %%
new['NRI_ID'] = new['NRI_ID'].str.replace('T', '')

#new.drop(1, inplace=True)
# Out:
# /tmp/ipykernel_111/4209321869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['NRI_ID'] = new['NRI_ID'].str.replace('T', '')

# %%
#it is int, so 0 cannot show, I want transform to transform int to string
new['NRI_ID'] = new['NRI_ID'].astype(str)
# Out:
# /tmp/ipykernel_111/1615187728.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['NRI_ID'] = new['NRI_ID'].astype(str)

# %%
new.NRI_ID.head()
# Out:
# 4200    06001400100
# 4201    06001400200
# 4202    06001400300
# 4203    06001400400
# 4204    06001400500
# Name: NRI_ID, dtype: object

# %% [markdown]
# Now we can see the 0 before 6

# %%
#new.Geo_FIPS=new.NRI_ID  Change the original name to GEO_id
new = new.rename(columns={'GEO_id': 'FIPS'})
# Out:
#        OBJECTID         FIPS       STATE STATEABBRV STATEFIPS     COUNTY  \
# 4200       4201  06001400100  California         CA        06    Alameda
# 4201       4202  06001400200  California         CA        06    Alameda
# 4202       4203  06001400300  California         CA        06    Alameda
# 4203       4204  06001400400  California         CA        06    Alameda
# 4204       4205  06001400500  California         CA        06    Alameda
# ...         ...          ...         ...        ...       ...        ...
# 11035     11036  06073017305  California         CA        06  San Diego
# 11036     11037  06073017306  California         CA        06  San Diego
# 11037     11038  06073017307  California         CA        06  San Diego
# 11038     11039  06073017308  California         CA        06  San Diego
# 11039     11040  06073017403  California         CA        06  San Diego
#
#       COUNTYTYPE  COUNTYFIPS  STCOFIPS   TRACT  ...  WNTW_ALRP  WNTW_ALRA  \
# ...

# %%
new.head()
# Out:
#       OBJECTID         FIPS       STATE STATEABBRV STATEFIPS   COUNTY  \
# 4200      4201  06001400100  California         CA        06  Alameda
# 4201      4202  06001400200  California         CA        06  Alameda
# 4202      4203  06001400300  California         CA        06  Alameda
# 4203      4204  06001400400  California         CA        06  Alameda
# 4204      4205  06001400500  California         CA        06  Alameda
#
#      COUNTYTYPE  COUNTYFIPS  STCOFIPS   TRACT  ...  WNTW_ALRP  WNTW_ALRA  \
# 4200     County           1      6001  400100  ...        0.0        0.0
# 4201     County           1      6001  400200  ...        0.0        0.0
# 4202     County           1      6001  400300  ...        0.0        0.0
# 4203     County           1      6001  400400  ...        0.0        0.0
# 4204     County           1      6001  400500  ...        0.0        0.0
#
#       WNTW_ALR_NPCTL  WNTW_RISKV  WNTW_RISKS  WNTW_RISKR     NRI_VER  \
# ...

# %%
#find the columns that comtains null value
new.columns[new.isna().all()].tolist()
# Out:
# ['CFLD_EVNTS',
#  'ERQK_EVNTS',
#  'ISTM_EVNTS',
#  'ISTM_AFREQ',
#  'ISTM_EXP_AREA',
#  'ISTM_EXPB',
#  'ISTM_EXPP',
#  'ISTM_EXPPE',
#  'ISTM_EXPT',
#  'ISTM_HLRB',
#  'ISTM_HLRP',
#  'ISTM_EALB',
#  'ISTM_EALP',
#  'ISTM_EALPE',
#  'ISTM_EALT',
#  'ISTM_EALS',
#  'ISTM_ALRB',
#  'ISTM_ALRP',
#  'ISTM_ALR_NPCTL',
#  'ISTM_RISKV',
#  'ISTM_RISKS',
#  'WFIR_EVNTS']

# %% [markdown]
# I want to delete those empty columns to make sure the survey is correct

# %%
# axis = 0 delete rows and axis = 1 delete columns with null
new = new.dropna(axis=1,how="all")

# %%
new.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6840 entries, 4200 to 11039
# Data columns (total 448 columns):
#  #    Column          Non-Null Count  Dtype
# ---   ------          --------------  -----
#  0    OBJECTID        6840 non-null   int64
#  1    GEO_id          6840 non-null   object
#  2    STATE           6840 non-null   object
#  3    STATEABBRV      6840 non-null   object
#  4    STATEFIPS       6840 non-null   object
#  5    COUNTY          6840 non-null   object
#  6    COUNTYTYPE      6840 non-null   object
#  7    COUNTYFIPS      6840 non-null   int64
#  8    STCOFIPS        6840 non-null   int64
#  9    TRACT           6840 non-null   int64
#  10   TRACTFIPS       6840 non-null   int64
#  11   POPULATION      6839 non-null   float64
#  12   BUILDVALUE      6839 non-null   float64
#  13   AGRIVALUE       6839 non-null   float64
#  14   AREA            6839 non-null   float64
#  15   RISK_VALUE      6839 non-null   float64
# ...

# %%
new.shape
# Out:
# (6840, 448)

# %%
new.head(1)
# Out:
#       OBJECTID       GEO_id       STATE STATEABBRV STATEFIPS   COUNTY  \
# 4200      4201  06001400100  California         CA        06  Alameda
#
#      COUNTYTYPE  COUNTYFIPS  STCOFIPS   TRACT  ...  WNTW_ALRP  WNTW_ALRA  \
# 4200     County           1      6001  400100  ...        0.0        0.0
#
#       WNTW_ALR_NPCTL  WNTW_RISKV  WNTW_RISKS  WNTW_RISKR     NRI_VER  \
# 4200             0.0         0.0         0.0   No Rating  March 2023
#
#                                     GlobalID  SHAPE_Length  SHAPE_Area
# 4200  {2D5079E8-560C-43BD-84C4-9104A35D8A9B}      0.143536    0.000711
#
# [1 rows x 448 columns]

# %% [markdown]
# meke sure the null columns are gone

# %%
# There are too many columns, I want to field them and focus my attention only on SWND
columns_to_keep = ['SWND_EVNTS',
                   'SWND_AFREQ',
                   'SWND_EXP_AREA',
                   'SWND_EXPB',
                   'SWND_EXPP',
                   'SWND_EXPPE',
                   'SWND_EXPT',
                   'SWND_EALP',
                   'SWND_EALR',
                   'SWND_RISKR']
# add it to a new dataframe
new2 = new[columns_to_keep]

# %%
new2
# Out:
#        SWND_EVNTS  SWND_AFREQ  SWND_EXP_AREA     SWND_EXPB  SWND_EXPP  \
# 4200          2.0    0.033032       2.708882  1.277580e+09     3038.0
# 4201          1.0    0.028775       0.228758  5.261868e+08     1995.0
# 4202          1.0    0.027851       0.433226  9.030828e+08     5504.0
# 4203          2.0    0.030702       0.279293  6.635660e+08     4112.0
# 4204          2.0    0.032045       0.230655  4.978154e+08     3644.0
# ...           ...         ...            ...           ...        ...
# 11035         7.0    0.190993       1.639956  6.790271e+08     3100.0
# 11036         5.0    0.133685       1.833380  1.041790e+09     2855.0
# 11037         5.0    0.146652       0.574672  7.843912e+08     2264.0
# 11038         5.0    0.133685       0.491083  6.461234e+08     3178.0
# 11039         NaN         NaN            NaN           NaN        NaN
#
#          SWND_EXPPE     SWND_EXPT  SWND_EALP SWND_EALR SWND_RISKR
# ...

# %%
# change the columns name
new2.columns = ['event',
                'AFREQ',
                'EXP_AREA',
                'EXPB',
                'STATEABBRV',
               'EXPPE',
               'EXPT',
               'EALP',
               'EALR', 
                'RISKR']

# %%
new2.head
# Out:
# <bound method NDFrame.head of        event     AFREQ  EXP_AREA          EXPB  STATEABBRV         EXPPE  \
# 4200     2.0  0.033032  2.708882  1.277580e+09      3038.0  3.524080e+10
# 4201     1.0  0.028775  0.228758  5.261868e+08      1995.0  2.314200e+10
# 4202     1.0  0.027851  0.433226  9.030828e+08      5504.0  6.384640e+10
# 4203     2.0  0.030702  0.279293  6.635660e+08      4112.0  4.769920e+10
# 4204     2.0  0.032045  0.230655  4.978154e+08      3644.0  4.227040e+10
# ...      ...       ...       ...           ...         ...           ...
# 11035    7.0  0.190993  1.639956  6.790271e+08      3100.0  3.596000e+10
# 11036    5.0  0.133685  1.833380  1.041790e+09      2855.0  3.311800e+10
# 11037    5.0  0.146652  0.574672  7.843912e+08      2264.0  2.626240e+10
# 11038    5.0  0.133685  0.491083  6.461234e+08      3178.0  3.686480e+10
# 11039    NaN       NaN       NaN           NaN         NaN           NaN
#
#                EXPT      EALP      EALR     RISKR
# ...

# %%
# calculate the mean of event value
new2['event'].mean
# Out:
# <bound method Series.mean of 4200     2.0
# 4201     1.0
# 4202     1.0
# 4203     2.0
# 4204     2.0
#         ...
# 11035    7.0
# 11036    5.0
# 11037    5.0
# 11038    5.0
# 11039    NaN
# Name: event, Length: 6840, dtype: float64>

# %%
# get the meedian number of event
new2['event'].median
# Out:
# <bound method Series.median of 4200     2.0
# 4201     1.0
# 4202     1.0
# 4203     2.0
# 4204     2.0
#         ...
# 11035    7.0
# 11036    5.0
# 11037    5.0
# 11038    5.0
# 11039    NaN
# Name: event, Length: 6840, dtype: float64>

# %%
#get some stats
new2['event'].describe
# Out:
# <bound method NDFrame.describe of 4200     2.0
# 4201     1.0
# 4202     1.0
# 4203     2.0
# 4204     2.0
#         ...
# 11035    7.0
# 11036    5.0
# 11037    5.0
# 11038    5.0
# 11039    NaN
# Name: event, Length: 6840, dtype: float64>

# %%
# plot it as a historgram with 50 bins
new2['event'].plot.hist(x='event',bins=50,color='Purple')
# Out:
# <Axes: ylabel='Frequency'>

# %%
new2['AFREQ'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# box plot: notice the different syntax to generate it
new2.boxplot(column=['AFREQ'])
# Out:
# <Axes: >

# %% [markdown]
# I want to sort the event and let it downward

# %%
new2_sorted = new2.sort_values(by='event',ascending = False)

# %%
new2_sorted
# Out:
#        event     AFREQ     EXP_AREA          EXPB  STATEABBRV         EXPPE  \
# 10459   11.0  0.307094    54.333439  7.194375e+08      3714.0  4.308240e+10
# 5272    11.0  0.302568  2334.505761  4.109724e+08       739.0  8.572400e+09
# 5273    11.0  0.310351    45.653371  6.934280e+08      2698.0  3.129680e+10
# 10503   11.0  0.299715  2837.584161  1.358791e+09      2018.0  2.340880e+10
# 10504   11.0  0.307349    44.889495  5.444354e+08      1208.0  1.401280e+10
# ...      ...       ...          ...           ...         ...           ...
# 5274     1.0  0.022139   319.955371  7.626737e+08      2942.0  3.412720e+10
# 9888     1.0  0.021350     0.444198  4.268553e+08      3519.0  4.082040e+10
# 8177     0.0  0.000000     2.820403  9.609776e+08      3356.0  3.892960e+10
# 8178     0.0  0.000000     1.494969  1.022883e+09      4330.0  5.022800e+10
# 11039    NaN       NaN          NaN           NaN         NaN           NaN
#
# ...

# %%
new2.plot.scatter(x='event',y='STATEABBRV')
# Out:
# <Axes: xlabel='event', ylabel='STATEABBRV'>

# %%
# plot it
new2_sorted.head(10).plot.bar(x='event')
# Out:
# <Axes: xlabel='event'>

# %%
#Importing the folium library
import folium

# %%
import geopandas as gpd

# %%
# read in a geojson file 
tracts=gpd.read_file('data/Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
tracts.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
# get more information of this dataset
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       2495 non-null   int64
#  1   CT20           2495 non-null   object
#  2   LABEL          2495 non-null   object
#  3   ShapeSTArea    2495 non-null   float64
#  4   ShapeSTLength  2495 non-null   float64
#  5   geometry       2495 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(2)
# memory usage: 117.1+ KB

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']
tracts['FIPS']
# Out:
# 0       06037101110
# 1       06037101122
# 2       06037101220
# 3       06037101221
# 4       06037101222
#            ...
# 2490    06037980035
# 2491    06037980036
# 2492    06037980037
# 2493    06037980038
# 2494    06037980039
# Name: FIPS, Length: 2495, dtype: object

# %% [markdown]
# merge new2 and tracts

# %%
tracts = tracts[['FIPS','geometry']]
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  06037101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  06037101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  06037101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  06037101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
#tracts_social=tracts.merge(new2,on="FIPS")

# %%
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  06037101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  06037101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  06037101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  06037101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...
